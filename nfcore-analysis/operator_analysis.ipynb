# %% [markdown]
# Old Analysis of operator domain, with different approach and different bio tools

# %% [markdown]
# # Operator domain data analysis
# - Tables 3 and 4 in the paper number of tools used in the workflows
# - (e.g., bioinformatics tools such as samtools, bcftools)
#
# In this seperate notebook, we want to analyze the operators in the nf-core git-repos.
# The target operators are provided in two excel sheets and can be found in the folder 'data'. Also we want to consider the operators from the Nexflow documentation here: https://www.nextflow.io/docs/latest/operator.html

# %%
import pandas as pd

df_operators = pd.read_excel('./data/all_operator_dataset.xlsx')
#df_bioinformatic_tools = pd.read_excel('./data/bioinformatics_tools.xlsx')

pattern_list = df_operators['operator'].tolist()

print(pattern_list)

# %%
len(pattern_list)

# %%
df_operators_clustured = pd.read_csv('./data/operator_dataset_clustered.csv')

# %% [markdown]
# We have 6 unique domain groups: ["Bioinformatics", "Control flow", "File processing", "File system", "Code execution", "Data handling", "Misc", "Noise", "under 10"]
#
#
# e.g.: Assigned Group 0 = "Bioinformatics"
# if domain >= 6: "Other" domain

# %%
df_operators_clustured.head()

# %%
df_operators_clustured['Assigned Group'].unique()

# %%
df

# %% [markdown]
# # Operator domain data (all operators from csv) in processes

# %%
import os
import re
import csv
import pandas as pd

def find_operators_in_processes(directory, pattern_list, output_file_name):
    result_list = []

    for pipeline in os.listdir(directory):
        subdirectory_path = os.path.join(directory, pipeline)
        folder_name = os.path.basename(subdirectory_path)

        for root, dirs, files in os.walk(subdirectory_path):
            for filename in files:
                file_path = os.path.join(root, filename)
                
                if filename.endswith('.nf') or filename.endswith('.config'):
                    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
                        lines = file.readlines()
                    
                    process_flag = False
                    process_name = None
                    brace_stack = []

                    process_pattern = r'process\s+(\w+)\s*{'

                    for line_num, line in enumerate(lines):
                        stripped_line = line.strip()
                        
                        if line.strip().startswith(('#', '//', '*')):
                                continue

                        if re.search(process_pattern, stripped_line):
                            process_flag = True
                            process_match = re.search(process_pattern, stripped_line)
                            if process_match:
                                process_name = process_match.group(1)
                            print(f'Process {process_name} in filepath {file_path}')
                            brace_stack.append('{')

                        if '{' in stripped_line:
                            brace_stack.append('{')

                        if '}' in stripped_line:
                            if brace_stack:
                                brace_stack.pop()
                                if not brace_stack and process_flag:
                                    process_flag = False

                        if process_flag:
                            pattern_found = False
                            for pattern in pattern_list:

                                regex_pattern = re.compile(re.escape(pattern))
                                #regex_pattern = re.compile(r'(\.\s*|\s+)' + re.escape(pattern) + r'(\s+|\.\s*)')
                                if regex_pattern.search(stripped_line):
                                    result_list.append([folder_name, process_name, pattern, file_path, line_num+1, stripped_line])
                                    print(f'Operator found {pattern} with content: {stripped_line}')
                                    pattern_found = True

                    if brace_stack:
                        print("Error: Unclosed process block in file:", file_path)

    with open(f'./results/{output_file_name}.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['pipeline', 'process_name', 'operator', 'file_path', 'line_number', 'line_content'])
        writer.writerows(result_list)

# %%
directory_path = './git_repos'

df_operators = pd.read_excel('./data/all_operator_dataset.xlsx')
operator_list = [str(operator) for operator in df_operators['operator']]

output_file_name = 'all_operators_in_processes'

find_operators_in_processes(directory_path, operator_list, output_file_name)

# %% [markdown]
# Bioinformatic tools in processes

# %%
df_operators = pd.read_excel('./data/bioinformatics_tools.xlsx')
pattern_list = [str(pattern) for pattern in df_operators['operator']]

output_file_name = 'all_operators_in_processes'

find_operators_in_processes(directory_path, pattern_list, output_file_name)

# %% [markdown]
# # Parser for operator domain data occurences in config files

# %%
import os
import re
import csv
import pandas as pd

def find_operators_in_config(directory, pattern_list, output_file_name):
    result_list = []

    for pipeline in os.listdir(directory):
        subdirectory_path = os.path.join(directory, pipeline)
        folder_name = os.path.basename(subdirectory_path)

        for root, dirs, files in os.walk(subdirectory_path):
            for filename in files:
                file_path = os.path.join(root, filename)
                
                if filename.endswith('.config'):
                #if filename.endswith('.nf'):
                    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
                        lines = file.readlines()

                    for line_num, line in enumerate(lines):
                        stripped_line = line.strip()
                        
                        if line.strip().startswith(('#', '//', '*')):
                            continue
                        
                        for pattern in pattern_list:

                            regex_pattern = re.compile(re.escape(pattern))
                            if regex_pattern.search(stripped_line):
                                result_list.append([folder_name, pattern, file_path, line_num+1, stripped_line])
                                print(f'Operator found {pattern} with content: {stripped_line}')

    with open(f'./results/{output_file_name}.csv', 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['pipeline', 'operator', 'file_path', 'line_number', 'line_content'])
        writer.writerows(result_list)

# %%
'''directory_path = './git_repos'

df_operators = pd.read_excel('./data/all_operator_dataset.xlsx')
operator_list = [str(pattern) for pattern in df_operators['operator']]

output_file_name = 'all_operators_in_config'

find_operators_in_config(directory_path, operator_list, output_file_name)'''
# Out:
# "directory_path = './git_repos'\n\ndf_operators = pd.read_excel('./data/all_operator_dataset.xlsx')\noperator_list = [str(pattern) for pattern in df_operators['operator']]\n\noutput_file_name = 'all_operators_in_config'\n\nfind_operators_in_config(directory_path, operator_list, output_file_name)"

# %% [markdown]
# Bioinformatic tools

# %%
directory_path = './git_repos'

df_operators = pd.read_excel('./data/bioinformatics_tools.xlsx')
operator_list = [str(pattern) for pattern in df_operators['operator']]

output_file_name = 'bioinformatic_tools_in_config'

find_operators_in_config(directory_path, operator_list, output_file_name)
# Out:
# Operator found multiqc with content: skip_multiqc               = false
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: multiqc_logo               = null
# Operator found multiqc with content: max_multiqc_email_size     = '25.MB'
# Operator found multiqc with content: multiqc_methods_description = null
# Operator found fastp with content: path: { "${params.outdir}/fastp/${meta.id}" },
# Operator found fastp with content: path: { "${params.outdir}/fastp/${meta.id}/" },
# Operator found fastp with content: pattern: "*.fastp.fastq.gz"
# Operator found fastqc with content: path: { "${params.outdir}/fastqc/postassembly" },
# Operator found multiqc with content: ext.args   = params.multiqc_title ? "--title \"$params.multiqc_title\"" : ''
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found cutadapt with content: cutadapt_min_overlap = 3
# Operator found cutadapt with content: cutadapt_max_error_rate = 0.1
# Operator found qiime with content: qiime_adonis_formula = null
# Operator found cutadapt with content: skip_cutadapt          = false
# Operator found qiime with content: skip_qiime             = false
# Operator found qiime with content: skip_qiime_downstream  = false
# Operator found fastqc with content: skip_fastqc            = false
# Operator found multiqc with content: skip_multiqc           = false
# Operator found qiime with content: qiime_ref_taxonomy       = null
# Operator found qiime with content: qiime_ref_tax_custom     = null
# Operator found kraken2 with content: kraken2_ref_taxonomy     = null
# Operator found kraken2 with content: kraken2_assign_taxlevels = null
# Operator found kraken2 with content: kraken2_ref_tax_custom   = null
# Operator found kraken2 with content: kraken2_confidence       = 0.0
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: multiqc_logo               = null
# Operator found multiqc with content: max_multiqc_email_size     = '25.MB'
# Operator found multiqc with content: multiqc_methods_description = null
# Operator found qiime with content: validationSchemaIgnoreParams     = 'dada_ref_databases,qiime_ref_databases,sintax_ref_databases,kraken2_ref_databases,genomes,igenomes_base'
# Operator found kraken2 with content: validationSchemaIgnoreParams     = 'dada_ref_databases,qiime_ref_databases,sintax_ref_databases,kraken2_ref_databases,genomes,igenomes_base'
# Operator found qiime with content: test_qiimecustom   { includeConfig 'conf/test_qiimecustom.config'   }
# Operator found cutadapt with content: ext.args = params.skip_cutadapt ? 'cp' : 'ln -s'
# Operator found cutadapt with content: "-O ${params.cutadapt_min_overlap}",
# Operator found cutadapt with content: "-e ${params.cutadapt_max_error_rate}",
# Operator found cutadapt with content: path: { "${params.outdir}/cutadapt" },
# Operator found cutadapt with content: "-O ${params.cutadapt_min_overlap}",
# Operator found cutadapt with content: "-e ${params.cutadapt_max_error_rate}",
# Operator found cutadapt with content: path: { "${params.outdir}/cutadapt" },
# Operator found cutadapt with content: "-O ${params.cutadapt_min_overlap}",
# Operator found cutadapt with content: "-e ${params.cutadapt_max_error_rate}",
# Operator found cutadapt with content: path: { "${params.outdir}/cutadapt" },
# Operator found cutadapt with content: path: { "${params.outdir}/cutadapt" },
# Operator found cutadapt with content: path: { "${params.outdir}/cutadapt" },
# Operator found kraken2 with content: ext.args = "--use-names --confidence ${params.kraken2_confidence}"
# Operator found kraken2 with content: path: { "${params.outdir}/kraken2" },
# Operator found kraken2 with content: path: { "${params.outdir}/kraken2" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/taxonomy" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/taxonomy" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/input" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/input" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/abundance_tables" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/representative_sequences" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/abundance_tables" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/barplot_average" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/representative_sequences" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/abundance_tables" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/abundance_tables" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/representative_sequences" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/rel_abundance_tables" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/phylogenetic_tree" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/diversity" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2/diversity/beta_diversity" },
# Operator found qiime with content: path: { "${params.outdir}/qiime2" },
# Operator found multiqc with content: ext.args   = { params.multiqc_title ? "--title \"$params.multiqc_title\"" : '' }
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found qiime with content: qiime_ref_databases {
# Operator found qiime with content: file = [ "https://data.qiime2.org/2023.7/common/silva-138-99-seqs.qza", "https://data.qiime2.org/2023.7/common/silva-138-99-tax.qza" ]
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_silva138.sh"
# Operator found qiime with content: file = [ "https://data.qiime2.org/2023.7/common/silva-138-99-seqs.qza", "https://data.qiime2.org/2023.7/common/silva-138-99-tax.qza" ]
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_silva138.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_unite.sh"
# Operator found qiime with content: file = [ "https://data.qiime2.org/2023.7/tutorials/training-feature-classifiers/85_otus.fasta", "https://data.qiime2.org/2023.7/tutorials/training-feature-classifiers/85_otu_taxonomy.txt" ]
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_greengenes85.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_greengenes2022.sh"
# Operator found qiime with content: fmtscript = "taxref_reformat_qiime_greengenes2022.sh"
# Operator found kraken2 with content: kraken2_ref_databases {
# Operator found qiime with content: qiime_ref_taxonomy = "greengenes85"
# Operator found qiime with content: qiime_adonis_formula = "treatment1,mix8"
# Operator found kraken2 with content: kraken2_ref_taxonomy = "greengenes"
# Operator found fastqc with content: skip_fastqc = true
# Operator found fastqc with content: skip_fastqc = true
# Operator found qiime with content: skip_qiime = true
# Operator found qiime with content: qiime_ref_taxonomy = "greengenes85"
# Operator found qiime with content: qiime_adonis_formula = "habitat"
# Operator found qiime with content: skip_qiime = true
# Operator found cutadapt with content: skip_cutadapt = true
# Operator found cutadapt with content: skip_cutadapt = true
# Operator found qiime with content: skip_qiime = true
# Operator found qiime with content: skip_qiime = true
# Operator found qiime with content: qiime_ref_taxonomy = "greengenes85"
# Operator found fastqc with content: skip_fastqc = true
# Operator found qiime with content: nextflow run nf-core/ampliseq -profile test_qiimecustom,<docker/singularity> --outdir <OUTDIR>
# Operator found qiime with content: config_profile_description = 'Minimal test dataset to check --qiime_ref_tax_custom'
# Operator found qiime with content: qiime_ref_tax_custom = "https://raw.githubusercontent.com/nf-core/test-datasets/ampliseq/testdata/85_greengenes.fna.gz,https://raw.githubusercontent.com/nf-core/test-datasets/ampliseq/testdata/85_greengenes.tax.gz"
# Operator found qiime with content: skip_qiime_downstream = true
# Operator found kraken2 with content: kraken2_ref_tax_custom = "https://genome-idx.s3.amazonaws.com/kraken/16S_Greengenes13.5_20200326.tgz"
# Operator found kraken2 with content: kraken2_assign_taxlevels = "D,P,C,O"
# Operator found qiime with content: qiime_ref_tax_custom = "https://raw.githubusercontent.com/nf-core/test-datasets/ampliseq/testdata/85_greengenes.tar.gz"
# Operator found qiime with content: skip_qiime_downstream = true
# Operator found qiime with content: skip_qiime = true
# Operator found qiime with content: qiime_adonis_formula = "var2"
# Operator found bwa with content: aligner                    = 'bwa'
# Operator found bwa with content: bwa_min_score              = null
# Operator found fastqc with content: skip_fastqc                = false
# Operator found picard with content: skip_picard_metrics        = false
# Operator found multiqc with content: skip_multiqc               = false
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: multiqc_logo               = null
# Operator found multiqc with content: max_multiqc_email_size     = '25.MB'
# Operator found multiqc with content: multiqc_methods_description = null
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/CHM13/Sequence/BWAIndex/"
# Operator found bwa with content: bwamem2     = "${params.igenomes_base}/Homo_sapiens/UCSC/CHM13/Sequence/BWAmem2Index/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_5.0/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_5.0/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_5.0/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/BismarkIndex/"
# Operator found fastqc with content: if (!(params.skip_fastqc || params.skip_qc)) {
# Operator found fastqc with content: path: { "${params.outdir}/fastqc" },
# Operator found fastqc with content: path: { "${params.outdir}/fastqc/zips" },
# Operator found fastqc with content: '--fastqc',
# Operator found fastqc with content: path: { "${params.outdir}/trimgalore/fastqc" },
# Operator found fastqc with content: path: { "${params.outdir}/trimgalore/fastqc/zips" },
# Operator found samtools with content: path: { "${params.outdir}/${params.aligner}/library/samtools_stats" },
# Operator found bwa with content: if (params.aligner == 'bwa') {
# Operator found bwa with content: params.bwa_min_score ? " -T ${params.bwa_min_score}" : '',
# Operator found bowtie2 with content: if (params.aligner == 'bowtie2') {
# Operator found picard with content: path: { "${params.outdir}/${params.aligner}/merged_library/picard_metrics" },
# Operator found samtools with content: path: { "${params.outdir}/${params.aligner}/merged_library/samtools_stats" },
# Operator found samtools with content: path: { "${params.outdir}/${params.aligner}/merged_library/samtools_stats" },
# Operator found samtools with content: path: { "${params.outdir}/${params.aligner}/merged_library/samtools_stats" },
# Operator found picard with content: if (!params.skip_picard_metrics) {
# Operator found picard with content: path: { "${params.outdir}/${params.aligner}/merged_library/picard_metrics" },
# Operator found picard with content: path: { "${params.outdir}/${params.aligner}/merged_library/picard_metrics/pdf" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}" },
# Operator found macs2 with content: ext.args   = '-o ./ -p macs2_peak.mLb.clN'
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: ext.prefix = 'macs2_annotatePeaks.mLb.clN'
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus/deseq2" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_library/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found picard with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/picard_metrics" },
# Operator found samtools with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/samtools_stats" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}" },
# Operator found macs2 with content: ext.args   = '-o ./ -p macs2_peak.mRp.clN'
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: ext.prefix = 'macs2_annotatePeaks.mRp.clN'
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/qc" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus/deseq2" },
# Operator found macs2 with content: path: { "${params.outdir}/${params.aligner}/merged_replicate/macs2/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}/consensus" },
# Operator found multiqc with content: if (!params.skip_multiqc) {
# Operator found multiqc with content: ext.args   = params.multiqc_title ? "--title \"$params.multiqc_title\"" : ''
# Operator found multiqc with content: path: { "${params.outdir}/multiqc/${params.narrow_peak ? '/narrow_peak' : '/broad_peak'}" },
# Operator found kraken2 with content: kraken2db                       = ""
# Operator found fastqc with content: skip_fastqc                     = false
# Operator found fastp with content: skip_fastp                      = false
# Operator found kraken2 with content: skip_kraken2                    = false
# Operator found multiqc with content: skip_multiqc                    = false
# Operator found multiqc with content: multiqc_config                  = null
# Operator found multiqc with content: multiqc_title                   = null
# Operator found multiqc with content: multiqc_logo                    = null
# Operator found multiqc with content: max_multiqc_email_size          = '25.MB'
# Operator found multiqc with content: multiqc_methods_description     = null
# Operator found NanoPlot with content: path: { "${params.outdir}/QC_longreads/NanoPlot" },
# Operator found kraken2 with content: path: { "${params.outdir}/kraken2" },
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found fastqc with content: if (!params.skip_fastqc) {
# Operator found fastp with content: if (!params.skip_fastp) {
# Operator found fastp with content: pattern: "*.fastp.fastq.gz",
# Operator found fastqc with content: if (!params.skip_fastqc) {
# Operator found kraken2 with content: skip_kraken2 = true
# Operator found kraken2 with content: skip_kraken2 = true
# Operator found kraken2 with content: kraken2db = 'https://genome-idx.s3.amazonaws.com/kraken/k2_standard_8gb_20210517.tar.gz'
# Operator found kraken2 with content: skip_kraken2 = true
# Operator found kraken2 with content: skip_kraken2 = true
# Operator found kraken2 with content: kraken2db = "https://genome-idx.s3.amazonaws.com/kraken/16S_Greengenes13.5_20200326.tgz"
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: max_multiqc_email_size            = '25.MB'
# Operator found multiqc with content: skip_multiqc                      = false
# Operator found fastp with content: 'fastp' {
# Operator found bwa with content: 'bwa_index' {
# Operator found bwa with content: 'bwa_mem' {
# Operator found samtools with content: args2 = '-F 4' // samtools view options discarding unmapped reads
# Operator found samtools with content: 'samtools_sort' {
# Operator found samtools with content: 'samtools_index' {
# Operator found bcftools with content: 'bcftools_mpileup' {
# Operator found bcftools with content: 'bcftools_filter' {
# Operator found multiqc with content: 'multiqc' {
# Operator found multiqc with content: publish_dir     = 'multiqc'
# Operator found bcftools with content: 'bcftools_filter' {
# Operator found bcftools with content: 'bcftools_filter' {
# Operator found samtools with content: samtools_collate_fast      = false
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: multiqc_logo               = null
# Operator found multiqc with content: max_multiqc_email_size     = '25.MB'
# Operator found multiqc with content: multiqc_methods_description = null
# Operator found samtools with content: ext.args         = { params.samtools_collate_fast ? "-f -r " + params.reads_in_memory : "" }
# Operator found samtools with content: ext.args         = { params.samtools_collate_fast ? "-f -r " + params.reads_in_memory : "" }
# Operator found samtools with content: ext.args          = { params.samtools_collate_fast ? "-f -r " + params.reads_in_memory : "" }
# Operator found samtools with content: path: { "${params.outdir}/samtools" },
# Operator found samtools with content: path: { "${params.outdir}/samtools" },
# Operator found samtools with content: path: { "${params.outdir}/samtools" },
# Operator found samtools with content: samtools_collate_fast = true
# Operator found fastqc with content: skip_initial_fastqc = false
# Operator found fastqc with content: skip_trimming_fastqc = false
# Operator found samtools with content: skip_samtools_stats = false
# Operator found multiqc with content: multiqc_config = false
# Operator found multiqc with content: max_multiqc_email_size = 25.MB
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/Ensembl/GRCh37/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/NCBI/GRCh38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Mus_musculus/Ensembl/GRCm38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Arabidopsis_thaliana/Ensembl/TAIR10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bacillus_subtilis_168/Ensembl/EB2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bos_taurus/Ensembl/UMD3.1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Caenorhabditis_elegans/Ensembl/WBcel235/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Canis_familiaris/Ensembl/CanFam3.1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Danio_rerio/Ensembl/GRCz10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Drosophila_melanogaster/Ensembl/BDGP6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Equus_caballus/Ensembl/EquCab2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Escherichia_coli_K_12_DH10B/Ensembl/EB1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Gallus_gallus/Ensembl/Galgal4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Glycine_max/Ensembl/Gm01/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Macaca_mulatta/Ensembl/Mmul_1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Oryza_sativa_japonica/Ensembl/IRGSP-1.0/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Pan_troglodytes/Ensembl/CHIMP2.1.4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Rattus_norvegicus/Ensembl/Rnor_6.0/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BWAIndex/genome.fa"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BismarkIndex/"
# ...
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Saccharomyces_cerevisiae/Ensembl/R64-1-1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Schizosaccharomyces_pombe/Ensembl/EF2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sorghum_bicolor/Ensembl/Sbi1/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sus_scrofa/Ensembl/Sscrofa10.2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Zea_mays/Ensembl/AGPv3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg38/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Homo_sapiens/UCSC/hg19/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Mus_musculus/UCSC/mm10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Bos_taurus/UCSC/bosTau8/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Caenorhabditis_elegans/UCSC/ce10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Canis_familiaris/UCSC/canFam3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Danio_rerio/UCSC/danRer10/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Drosophila_melanogaster/UCSC/dm6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Equus_caballus/UCSC/equCab2/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Gallus_gallus/UCSC/galGal4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Pan_troglodytes/UCSC/panTro4/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Rattus_norvegicus/UCSC/rn6/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Saccharomyces_cerevisiae/UCSC/sacCer3/Sequence/BismarkIndex/"
# Operator found bwa with content: bwa         = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/BWAIndex/version0.6.0/"
# Operator found bowtie2 with content: bowtie2     = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/Bowtie2Index/"
# Operator found bismark with content: bismark     = "${params.igenomes_base}/Sus_scrofa/UCSC/susScr3/Sequence/BismarkIndex/"
# Operator found minimap2 with content: artic_minion_aligner       = 'minimap2'
# Operator found multiqc with content: multiqc_title              = null
# Operator found multiqc with content: multiqc_config             = null
# Operator found multiqc with content: max_multiqc_email_size     = '25.MB'
# Operator found multiqc with content: skip_multiqc               = false
# Operator found kraken2 with content: kraken2_db                 = 's3://ngi-igenomes/test-data/viralrecon/kraken2_human.tar.gz'
# Operator found kraken2 with content: kraken2_db_name            = 'human'
# Operator found kraken2 with content: kraken2_variants_host_filter = false
# Operator found kraken2 with content: kraken2_assembly_host_filter = true
# Operator found fastqc with content: skip_fastqc                = false
# Operator found kraken2 with content: skip_kraken2               = false
# Operator found fastp with content: skip_fastp                 = false
# Operator found cutadapt with content: skip_cutadapt              = false
# Operator found bcftools with content: consensus_caller           = 'bcftools'
# Operator found picard with content: skip_picard_metrics        = false
# Operator found bcftools with content: if (!variant_caller) { variant_caller = params.protocol == 'amplicon' ? 'ivar' : 'bcftools' }
# Operator found fastqc with content: if (!params.skip_fastqc) {
# Operator found fastqc with content: path: { "${params.outdir}/fastqc/raw" },
# Operator found fastp with content: if (!params.skip_fastp) {
# Operator found fastp with content: path: { "${params.outdir}/fastp" },
# Operator found fastp with content: path: { "${params.outdir}/fastp/log" },
# Operator found fastp with content: path: { "${params.outdir}/fastp" },
# Operator found fastqc with content: if (!params.skip_fastqc) {
# Operator found fastqc with content: path: { "${params.outdir}/fastqc/trim" },
# Operator found kraken2 with content: if (!params.skip_kraken2) {
# Operator found kraken2 with content: path: { "${params.outdir}/kraken2" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/log" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/unmapped" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found samtools with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/log" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found samtools with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found picard with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2" },
# Operator found samtools with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/samtools_stats" },
# Operator found picard with content: if (!params.skip_picard_metrics) {
# Operator found picard with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics" },
# Operator found picard with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics/pdf" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/picard_metrics/pdf" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/mosdepth/genome" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/mosdepth/genome" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/mosdepth/amplicon" },
# Operator found bowtie2 with content: path: { "${params.outdir}/variants/bowtie2/mosdepth/amplicon" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/ivar/bcftools_stats" },
# Operator found bcftools with content: if (variant_caller == 'bcftools') {
# Operator found bcftools with content: path: { "${params.outdir}/variants/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/bcftools/bcftools_stats" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/snpeff/bcftools_stats" },
# Operator found bcftools with content: variant_caller == 'bcftools' ? "-H -f '%CHROM\\t%POS\\t%REF\\t%ALT\\t%FILTER\\t[%DP\\t]\\t[%AD\\t]\\n'" : '',
# Operator found bcftools with content: ext.prefix = { "${meta.id}.bcftools_query" }
# Operator found bcftools with content: if (!params.skip_consensus && params.consensus_caller == 'bcftools') {
# Operator found bcftools with content: variant_caller == 'bcftools' ? "--include 'FORMAT/AD[:1] / FORMAT/DP >= 0.75'" : '',
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found bcftools with content: path: { "${params.outdir}/variants/${variant_caller}/consensus/bcftools" },
# Operator found cutadapt with content: if (params.protocol == 'amplicon' && !params.skip_cutadapt) {
# Operator found cutadapt with content: path: { "${params.outdir}/assembly/cutadapt/log" },
# Operator found fastqc with content: if (!params.skip_fastqc) {
# Operator found fastqc with content: path: { "${params.outdir}/assembly/cutadapt/fastqc" },
# Operator found cutadapt with content: path: { "${params.outdir}/assembly/cutadapt/fastqc" },
# Operator found multiqc with content: if (!params.skip_multiqc) {
# Operator found multiqc with content: params.multiqc_title ? "--title \"$params.multiqc_title\"" : ''
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found multiqc with content: pattern: 'multiqc*'
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found multiqc with content: path: { "${params.outdir}/multiqc" },
# Operator found bwa with content: params.artic_minion_aligner == 'bwa'    ? '--bwa'    : '--minimap2'
# Operator found minimap2 with content: params.artic_minion_aligner == 'bwa'    ? '--bwa'    : '--minimap2'
# Operator found samtools with content: path: { "${params.outdir}/${params.artic_minion_caller}/samtools_stats" },
# Operator found bcftools with content: path: { "${params.outdir}/${params.artic_minion_caller}/bcftools_stats" },
# Operator found bcftools with content: path: { "${params.outdir}/${params.artic_minion_caller}/snpeff/bcftools_stats" },
# Operator found bcftools with content: ext.prefix = { "${meta.id}.bcftools_query" }
# Operator found multiqc with content: if (!params.skip_multiqc) {
# Operator found multiqc with content: params.multiqc_title ? "--title \"$params.multiqc_title\"" : ''
# Operator found multiqc with content: path: { "${params.outdir}/multiqc/${params.artic_minion_caller}" },
# Operator found kraken2 with content: kraken2_db = 'https://raw.githubusercontent.com/nf-core/test-datasets/viralrecon/genome/kraken2/kraken2_hs22.tar.gz'
# Operator found bcftools with content: variant_caller = 'bcftools'
# Operator found kraken2 with content: kraken2_db = 'https://raw.githubusercontent.com/nf-core/test-datasets/viralrecon/genome/kraken2/kraken2_hs22.tar.gz'
# Operator found bcftools with content: variant_caller = 'bcftools'

# %% [markdown]
# # Bioinformatic tools in configuration files

# %%
import pandas as pd
import numpy as np

df_bioinformatics = pd.read_csv('./results/bioinformatic_tools_in_config.csv')
df_bioinformatics
# Out:
#         pipeline  operator                                          file_path  \
# 0       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 1       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 2       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 3       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 4       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# ...          ...       ...                                                ...
# 8299  viralrecon   multiqc  ./git_repos\viralrecon\conf\modules_nanopore.c...
# 8300  viralrecon   kraken2            ./git_repos\viralrecon\conf\test.config
# 8301  viralrecon  bcftools  ./git_repos\viralrecon\conf\test_full_sispa.co...
# 8302  viralrecon   kraken2      ./git_repos\viralrecon\conf\test_sispa.config
# 8303  viralrecon  bcftools      ./git_repos\viralrecon\conf\test_sispa.config
#
#       line_number                                       line_content
# 0             107                 skip_multiqc               = false
# 1             108                  multiqc_config             = null
# 2             109                  multiqc_title              = null
# 3             110                  multiqc_logo               = null
# 4             111               max_multiqc_email_size     = '25.MB'
# ...           ...                                                ...
# 8299          345  path: { "${params.outdir}/multiqc/${params.art...
# 8300           31  kraken2_db = 'https://raw.githubusercontent.co...
# 8301           26                        variant_caller = 'bcftools'
# 8302           29  kraken2_db = 'https://raw.githubusercontent.co...
# 8303           32                        variant_caller = 'bcftools'
#
# [8304 rows x 5 columns]

# %%
pipelines_total = df_bioinformatics.groupby('pipeline').size().reset_index(name='bioinformatic_occur')
config_count = df_bioinformatics.groupby('file_path').size().reset_index(name='bioinformatic_occur')

print(f'Matched in {len(pipelines_total)} pipelines and {len(config_count)} config files')
# Out:
# Matched in 88 pipelines and 332 config files

# %%
df_bioinformatics
# Out:
#         pipeline  operator                                          file_path  \
# 0       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 1       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 2       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 3       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# 4       airrflow   multiqc               ./git_repos\airrflow\nextflow.config
# ...          ...       ...                                                ...
# 8299  viralrecon   multiqc  ./git_repos\viralrecon\conf\modules_nanopore.c...
# 8300  viralrecon   kraken2            ./git_repos\viralrecon\conf\test.config
# 8301  viralrecon  bcftools  ./git_repos\viralrecon\conf\test_full_sispa.co...
# 8302  viralrecon   kraken2      ./git_repos\viralrecon\conf\test_sispa.config
# 8303  viralrecon  bcftools      ./git_repos\viralrecon\conf\test_sispa.config
#
#       line_number                                       line_content
# 0             107                 skip_multiqc               = false
# 1             108                  multiqc_config             = null
# 2             109                  multiqc_title              = null
# 3             110                  multiqc_logo               = null
# 4             111               max_multiqc_email_size     = '25.MB'
# ...           ...                                                ...
# 8299          345  path: { "${params.outdir}/multiqc/${params.art...
# 8300           31  kraken2_db = 'https://raw.githubusercontent.co...
# 8301           26                        variant_caller = 'bcftools'
# 8302           29  kraken2_db = 'https://raw.githubusercontent.co...
# 8303           32                        variant_caller = 'bcftools'
#
# [8304 rows x 5 columns]

# %%
bio_df = df_bioinformatics.groupby('operator').agg({'pipeline': 'nunique', 'file_path': 'nunique'}).reset_index().sort_values(by='pipeline', ascending=False)
#grouped_df = merged_df.groupby('Assigned Group').agg({'config_file': 'nunique', 'operator_in_file': 'nunique'}).reset_index()

# %%
bio_df.head()
# Out:
#    operator  pipeline  file_path
# 23  multiqc        83        140
# 5   bowtie2        63         84
# 6       bwa        63        106
# 4   bismark        57         59
# 11   fastqc        40         62

# %% [markdown]
# # Operator domain data analysis
#
# - we get all the lines with occuring operators, filter by length of operator due to noisy data!

# %%
import pandas as pd

df = pd.read_csv('./results/all_operators_in_config.csv')
df_operator_clustered = pd.read_csv('./data/operator_dataset_clustered.csv')

# %%
df = pd.read_csv('./results/all_operators_in_config.csv')

# %% [markdown]
# Here we filter by the length of the operator, due to noise in data results similar approach to GitLab Snakemake (https://gitlab.informatik.hu-berlin.de/pohlseba/github_scraping/-/blob/main/analysis/operators/operators.py, line 222)

# %%
df = df[df['operator'].str.len() > 3]

# %% [markdown]
# By applying that, we can make sure that every operator occures just once in a pipline and we dont count multiple occurences

# %%
# we get each operator occurence once per file from 76137 to 12132  entries

df = df.groupby(['pipeline', 'operator', 'file_path']).size().reset_index(name='operator_in_file')

# %%
df = df.rename(columns={'operator': 'Operator', 'file_path': 'config_file'})

# %%
merged_df = pd.merge(df, df_operator_clustered, on='Operator')

# %%
# 1022 configuration files
merged_df['config_file'].nunique()
# Out:
# 1022

# %% [markdown]
# Group by Assigned Group

# %%
# n = number of operators to be shown
def most_common_operators(x, n=4):
    return list(x.value_counts().head(n).index)

# %%
agg_bio = merged_df.groupby('Assigned Group').agg({'pipeline': 'nunique', 'config_file': 'nunique', 'operator_in_file': 'count', 'Operator': lambda x: most_common_operators(x)}).reset_index()
agg_bio
# Out:
#    Assigned Group  pipeline  config_file  operator_in_file  \
# 0               0        87          406               680
# 1               1        94          446               580
# 2               2        94          838              1113
# 3               3        13           22                22
# 4               4        94          715              2060
# 5               5         7           11                20
# 6               6        94         1013              7676
#
#                                  Operator
# 0        [fasta, fastq, fastqc, fastq.gz]
# 1  [docker, else, centrifuge, classifier]
# 2           [params, print, echo, paired]
# 3          [zcat, coverm, cpan, sourmash]
# 4    [script, singularity, report, conda]
# 5            [gzip, bgzip, gunzip, unzip]
# 6               [file, test, time, input]

# %%
plot = merged_df.groupby('Assigned Group', 'config_file').agg({'operator_in_file': 'nunique'}).reset_index()
plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'config_file'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16932\3853819567.py in ?()
# ----> 1 plot = merged_df.groupby('Assigned Group', 'config_file').agg({'operator_in_file': 'nunique'}).reset_index()
#       2 plot
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8246         from pandas.core.groupby.generic import DataFrameGroupBy
#    8247
#    8248         if level is None and by is None:
#    8249             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8250         axis = self._get_axis_number(axis)
#    8251
#    8252         return DataFrameGroupBy(
#    8253             obj=self,
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     511     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     512         try:
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named config_file for object type DataFrame

# %% [markdown]
# - Assigned Group 0:    bioinformatics tool
# - Assigned Group 1:    control flow
# - Assigned Group 2:    file processing
# - Assigned Group 3:    file system
# - Assigned Group 4:    code execution
# - Assigned Group 5:    data handling
# - Assigned Group 6:    other

# %% [markdown]
# # Analysis of operator domain data in processes

# %%
import pandas as pd

df = pd.read_csv('./results/all_operators_in_processes.csv')

df_operator_clustered = pd.read_csv('./data/operator_dataset_clustered.csv')

# %%
df = df[df['operator'].str.len() > 3]

# %%
df = df.rename(columns={'operator': 'Operator'})

# %%
merged_df = pd.merge(df, df_operator_clustered, on='Operator')

# %%
grouped_df = merged_df.groupby('Assigned Group').agg({'pipeline': 'nunique', 'process_name': 'nunique', 'Operator': 'count', 'file_path': 'nunique'}).reset_index()

# %% [markdown]
# Add ratio = # occuring processes /# total rules

# %%
sum_processes = merged_df['process_name'].nunique()

# %%
sum_processes
# Out:
# 1982

# %%
grouped_df['ratio'] = grouped_df['process_name']/sum_processes

# %%
grouped_df
# Out:
#    Assigned Group  pipeline  process_name  Operator  file_path     ratio
# 0               0        88           863      9315       1269  0.435419
# 1               1        93          1588      4045       2463  0.801211
# 2               2        94          1622      8498       1943  0.818365
# 3               3        36            35       120         42  0.017659
# 4               4        94          1979     18899       2573  0.998486
# 5               5        70           187      1120        283  0.094349
# 6               6        94          1982     33788       2576  1.000000
